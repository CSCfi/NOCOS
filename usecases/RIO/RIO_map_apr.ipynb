# %%
# %%capture cap
# %run desp-authentication.py
# Out:
# Username:  qinghuai925
# Password:  ········

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %%
import earthkit.data
import earthkit.plots
import earthkit.regrid
from polytope.api import Client
import numpy as np
import glob
import xarray as xr
import earthkit.data
import matplotlib.pyplot as plt
import os
import numpy as np
from pathlib import Path
import os, glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from tqdm.auto import tqdm
from dask.diagnostics import ProgressBar
import matplotlib.dates as mdates
import sys
from pathlib import Path

# %%
# repo root: NOCOSRIOgit
repo_root = Path.cwd().resolve().parents[1]
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from common import download_icedata_c
from common import data_fetching
from common import config
from common import processing
from common.download_icedata_c import request_icedata_subarea

# %%
import os

datastoragedir = '/work/data/zhang/NOCOSRIOgit/usecases/RIO/data'
os.makedirs(datastoragedir, exist_ok=True)   # <-- create parents if missing

dataICE1month = request_icedata_subarea(
    activity='ScenarioMIP', experiment='SSP3-7.0', model='IFS-NEMO',
    date='20390801', subarea="Arctic", param="263008",
    datadir=datastoragedir
)
# Out:
# 2025-09-17 14:31:44 - INFO - Key read from /home/users/zhang/.polytopeapirc
# 2025-09-17 14:31:44 - INFO - Sending request...
# {'request': 'activity: ScenarioMIP\n'
#             'area: 90/-180/70/180\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             "date: '20390801'\n"
#             'experiment: SSP3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             'grid: O2560\n'
#             'levtype: o2d\n'
#             'model: IFS-NEMO\n'
#             "param: '263008'\n"
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-09-17 14:31:44 - INFO - Polytope user key found in session cache for user zhang
# Looking for previously downloaded data in: /work/data/zhang/NOCOSRIOgit/usecases/RIO/data
# File name to look for: icedata_ScenarioMIP_SSP3-7.0_IFS-NEMO_20390801_Arctic_263008.grb
# No datadir given or no existing data file found. I will request data from Polytope...
# {'activity': 'ScenarioMIP', 'class': 'd1', 'dataset': 'climate-dt', 'date': '20390801', 'experiment': 'SSP3-7.0', 'expver': '0001', 'generation': '1', 'levtype': 'o2d', 'model': 'IFS-NEMO', 'param': '263008', 'realization': '1', 'resolution': 'high', 'stream': 'clte', 'time': '0000', 'type': 'fc', 'grid': 'O2560', 'area': '90/-180/70/180'}
# 2025-09-17 14:31:46 - INFO - Request accepted. Please poll ./cf98fa01-43a3-4942-a4e3-d280bffa2bf0 for status
# 2025-09-17 14:31:46 - INFO - Polytope user key found in session cache for user zhang
# 2025-09-17 14:31:46 - INFO - Checking request status (cf98fa01-43a3-4942-a4e3-d280bffa2bf0)...
# 2025-09-17 14:31:46 - INFO - The current status of the request is 'queued'
# 2025-09-17 14:31:47 - INFO - The current status of the request is 'processing'
# 2025-09-17 14:31:53 - INFO - The current status of the request is 'processed'
# cf98fa01-43a3-4942-a4e3-d280bffa2bf0.grib:   0%|          | 0.00/429k [00:00<?, ?B/s]
# Saving data to: /work/data/zhang/NOCOSRIOgit/usecases/RIO/data/icedata_ScenarioMIP_SSP3-7.0_IFS-NEMO_20390801_Arctic_263008.grb

# %%
LIVE_REQUEST = True

# %%
request = {
    'activity': 'ScenarioMIP',
    'class': 'd1',
    'dataset': 'climate-dt',
    'experiment': 'SSP3-7.0',
    'expver': '0001',
    'generation': '1',
    'levtype': 'o2d',
    'model': 'IFS-NEMO',
    'param': '263008',  # Time-mean sea ice volume per unit area
    'realization': '1',
    'resolution': 'high',
    'stream': 'clte',
    'date': '20390801',
    'time': '0000',
    'grid': 'O2560',             
    'area' : '90/-180/70/180',
    'type': 'fc',
}
