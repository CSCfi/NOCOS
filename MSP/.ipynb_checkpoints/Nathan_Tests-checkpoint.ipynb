# %%
import numpy as np
import xarray as xr
import earthkit.data
import earthkit.plots
import earthkit.regrid
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
request = {
     'activity': 'ScenarioMIP',
     'class': 'd1',
     'dataset': 'climate-dt',
     'date': '20200101/20200102',
     'experiment': 'SSP3-7.0',
     'expver': '0001',
     'generation': '1',
     'levtype': 'o3d',
     'levelist': '1', 
     'model': 'ICON', #IFS-NEMO
     'param': '263500',
     'realization': '1',
     'resolution': 'high',
     'stream': 'clte',
     'time': '0000', # '0100/0200/0300/0400/0500/0600'
     'type': 'fc'
 }

# %%
data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
# Out:
# 2025-01-20 14:56:41 - INFO - Key read from /home/ubuntu/.polytopeapirc
# 2025-01-20 14:56:41 - INFO - Sending request...
# {'request': 'activity: ScenarioMIP\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             'date: 20200101/20200102\n'
#             'experiment: SSP3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             "levelist: '1'\n"
#             'levtype: o3d\n'
#             'model: ICON\n'
#             "param: '263501'\n"
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-01-20 14:56:41 - INFO - Polytope user key found in session cache for user ubuntu
# 2025-01-20 14:56:41 - INFO - Request accepted. Please poll ./f5ea1e78-ef81-473c-b4df-3d800268bc4a for status
# 2025-01-20 14:56:41 - INFO - Polytope user key found in session cache for user ubuntu
# 2025-01-20 14:56:41 - INFO - Checking request status (./f5ea1e78-ef81-473c-b4df-3d800268bc4a)...
# 2025-01-20 14:56:41 - INFO - The current status of the request is 'processing'
# ---------------------------------------------------------------------------
# HTTPResponseError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
#
# File ~/.local/lib/python3.10/site-packages/earthkit/data/sources/__init__.py:153, in from_source(name, lazily, *args, **kwargs)
#     151 while src is not prev:
#     152     prev = src
# --> 153     src = src.mutate()
#     154 return src
#
# File ~/.local/lib/python3.10/site-packages/earthkit/data/sources/polytope.py:91, in Polytope.mutate(self)
#      90 def mutate(self) -> Source:
# ---> 91     pointers = self.client.retrieve(
#      92         self.request["dataset"],
#      93         self.request["request"],
#      94         pointer=True,
#      95         asynchronous=False,
#      96     )
#      98     urls = [p["location"] for p in pointers]
#      99     LOG.debug(f"{urls=}")
#
# File ~/.local/lib/python3.10/site-packages/polytope/api/helpers.py:197, in wraps.<locals>.wrapper.<locals>.decorated(self, *args, **kwargs)
#     196 def decorated(self, *args, **kwargs):
# --> 197     return fun(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polytope/api/helpers.py:229, in authenticated.<locals>.decorated(self, *args, **kwargs)
#     227     raise e
#     228 # try:
# --> 229 return method(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polytope/api/helpers.py:197, in wraps.<locals>.wrapper.<locals>.decorated(self, *args, **kwargs)
#     196 def decorated(self, *args, **kwargs):
# --> 197     return fun(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polytope/api/Client.py:202, in Client.retrieve(self, *args, **kwargs)
#     199 @authenticated
#     200 @wraps(RequestManager.retrieve)
#     201 def retrieve(self, *args, **kwargs):
# --> 202     return self.request_manager.retrieve(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/polytope/api/RequestManager.py:450, in RequestManager.retrieve(self, name, request, output_file, inline_request, asynchronous, max_attempts, attempt_period, append, pointer)
#     448         request_results[i] = Result(request_url, output_file, append, self)
#     449     else:
# --> 450         request_results[i] = self.download(
#     451             request_url, output_file, asynchronous, max_attempts, attempt_period, append, pointer
#     452         )
#     454     append = True
#     456 for warning in warnings:
#
# File ~/.local/lib/python3.10/site-packages/polytope/api/RequestManager.py:692, in RequestManager.download(self, request_id, output_file, asynchronous, max_attempts, attempt_period, append, pointer)
#     688     e = helpers.RetriesExceededError(
#     689         attempts=describe_max_attempts, situation=situation, url=url, method=method, request_content=headers
#     690     )
#     691     raise e
# --> 692 response, response_messages = helpers.try_request(
#     693     method,
#     694     situation=situation,
#     695     expected=expected_responses,
#     696     logger=self._logger,
#     697     stream=True,
#     698     url=url,
#     699     headers=headers,
#     700     skip_tls=self.config.get()["skip_tls"],
#     701 )
#     702 if response.status_code == requests.codes.ok:
#     703     last_status = "processed"
#
# File ~/.local/lib/python3.10/site-packages/polytope/api/helpers.py:593, in try_request(method, situation, expected, logger, stream, skip_tls, **kwargs)
#     590     logger.warning("Maximum HTTP request retries reached")
#     591     raise e
# --> 593 response_title, response_messages = process_response(
#     594     response, situation, url, method, stream, request_content, expected
#     595 )
#     597 logger.debug("Polytope client received HTTP " + response_title)
#     599 return response, response_messages
#
# File ~/.local/lib/python3.10/site-packages/polytope/api/helpers.py:523, in process_response(response, situation, url, method, stream, request_content, expected)
#     521     if response.status_code == 401 and "expired" in response_messages[0]:
#     522         e.__class__ = "ExpiredCredentialsError"
# --> 523     raise e
#     524 elif response.status_code not in expected:
#     525     e.description = "Unexpected HTTP response from the server."
#
# HTTPResponseError: Polytope error
# Situation: trying to download data
# Description: HTTP CLIENT ERROR (400)
# URL: https://polytope.lumi.apps.dte.destination-earth.eu:443/api/v1/requests/./f5ea1e78-ef81-473c-b4df-3d800268bc4a
# HTTP method: GET
# Request header/body contents:
# {'headers': {'Authorization': 'Bearer **********6dTg'}, 'json': None}
# Expected responses: 200, 202
# Received response: CLIENT ERROR (400)
# Details:
# Request failed with error:
# Failed to finalize request: [<class 'ValueError'>] No data retrieved
# No data retrieved

# %%
out_grid = {"grid": [0.1,0.1]}
r = earthkit.regrid.interpolate(data, out_grid=out_grid, method="linear")
d = r.data()
lat = d[0]
lon = d[1]
vals = d[2:]
lat.shape, lon.shape, vals.shape

# %%
ds = r.to_xarray()
ds

# %%
central_latitude = 58
central_longitude = 8
false_easting = 60
false_northing = 60
extend = [-5, 28, 48, 66]

coastlines = cfeature.GSHHSFeature(scale='high',linewidths=0.25, edgecolor='k', facecolor='0.8')
fig, ax = plt.subplots(subplot_kw={"projection": ccrs.Stereographic(central_latitude=central_latitude, central_longitude=central_longitude, false_easting=false_easting, false_northing=false_northing)},)
p = ds["avg_so"].isel(levelist=0,forecast_reference_time=0).plot(
    x='longitude',
    y='latitude',
    transform=ccrs.PlateCarree(),
    #cbar_kwargs={'orientation': 'vertical', 'label': label},
    cmap=None, 
    norm=None,
    )
ax.set_extent(extend)

# %%
# Try some processing by plotting the mean SST over the Baltic for 1 year
import pandas
from datetime import date, timedelta
sdate = '20200101'
edate = '20201231'
date_ranges = pandas.date_range(sdate, edate,freq='d')
date_str = ""
for f in date_ranges: 
    date_str = date_str + f.strftime("%Y%m%d") + '/'
date_str = date_str[:-1]
#print(date_str)

# %%
request = {
     'activity': 'ScenarioMIP',
     'class': 'd1',
     'dataset': 'climate-dt',
     'date': '',
     'experiment': 'SSP3-7.0',
     'expver': '0001',
     'generation': '1',
     'levtype': 'o3d',
     'levelist': '1', 
     'model': 'IFS-NEMO',
     'param': '263500',
     'realization': '1',
     'resolution': 'high',
     'stream': 'clte',
     'time': '0000', # '0100/0200/0300/0400/0500/0600'
     'type': 'fc'
 }
data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
# Out:
# 2025-01-20 15:23:08 - INFO - Key read from /home/ubuntu/.polytopeapirc
# 2025-01-20 15:23:08 - INFO - Sending request...
# {'request': 'activity: ScenarioMIP\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             'date: '
#             '\n'
#             'experiment: SSP3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             "levelist: '1'\n"
#             'levtype: o3d\n'
#             'model: IFS-NEMO\n'
#             "param: '263500'\n"
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-01-20 15:23:08 - INFO - Polytope user key found in session cache for user ubuntu
# 2025-01-20 15:23:08 - INFO - Request accepted. Please poll ./e1ead3e1-a2ff-41b0-9766-d8dc938526b7 for status
# 2025-01-20 15:23:08 - INFO - Polytope user key found in session cache for user ubuntu
# 2025-01-20 15:23:08 - INFO - Checking request status (./e1ead3e1-a2ff-41b0-9766-d8dc938526b7)...
# 2025-01-20 15:23:09 - INFO - The current status of the request is 'queued'
# 2025-01-20 15:23:10 - INFO - The current status of the request is 'processing'
# 2025-01-20 15:23:13 - INFO - The current status of the request is 'processed'

# %%
out_grid = {"grid": [0.1,0.1]}
r = earthkit.regrid.interpolate(data, out_grid=out_grid, method="linear")
ds = r.to_xarray()
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:                  (forecast_reference_time: 31, latitude: 1801,
#                               longitude: 3600)
# Coordinates:
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 248B 20...
#   * latitude                 (latitude) float64 14kB 90.0 89.9 ... -89.9 -90.0
#   * longitude                (longitude) float64 29kB 0.0 0.1 ... 359.8 359.9
# Data variables:
#     avg_so                   (forecast_reference_time, latitude, longitude) float64 2GB ...
# Attributes: (12/14)
#     param:          avg_so
#     standard_name:  unknown
#     long_name:      Time-mean sea water practical salinity
#     paramId:        263500
#     class:          d1
#     stream:         clte
#     ...             ...
#     expver:         0001
#     date:           20200101
#     time:           0
#     levelist:       1
#     Conventions:    CF-1.8
#     institution:    ECMWF

# %%
fig, ax = plt.subplots()
p = ds["avg_so"].where(ds["avg_so"] != 0).sel(longitude=slice(9, 31.7), latitude=slice(67, 50)).mean('latitude').mean('longitude').plot(
    x='forecast_reference_time',
    )
